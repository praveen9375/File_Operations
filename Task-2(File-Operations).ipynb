# %%
def extract_domain_name(url):
    
    url_without_protocol = url.split("://")[1] if "://" in url else url
    return (url_without_protocol.split("/")[0])
url = "https://www.google.com/search?q=python"
extract_domain_name(url)
# Out:
# 'www.google.com'

# %%
# a file named "geek", will be opened with the reading mode.
file = r'''C:\Users\PraVEen\Downloads\0502_Qonly1.txt'''
file_dir = open(file, 'r')
# This will print every line one by one in the file
for each in file:
    print (each)
# Out:
# C
# :
# \
# U
# s
# e
# r
# s
# \
# P
# r
# a
# V
# E
# e
# n
# \
# D
# o
# w
# n
# l
# o
# a
# d
# s
# \
# 0
# 5
# 0
# 2
# _
# Q
# o
# n
# l
# y
# 1
# .
# t
# x
# t

# %%
# Python code to illustrate read() mode
file = open(r"C:\Users\PraVEen\Downloads\0502_Qonly1.txt", "r")
print (file.read())
# Out:
# may-02:
# topics:
# 	1. parsing samples
# 	2. file handling
# 	3. json
# -- use of ternary operator!!
# 1. parsing samples
# def extract_domain_name(url):
#
#     url.split("://")[1] if "://" in url else url
#
#     # Remove path
#     return = url_without_protocol.split("/")[0]
#
# # Test the function
# url = "https://www.google.com/search?q=python"
#
#
# 2. file handling
# - study on read, write
# - use of with
# - read & read(n), readline, readlines [where does pointer end?]
# - write, writelines
# - exceptions that occurs while file operations [FileNotFoundError, PermissionError, IOError]
# example:
# 	filename = "example.txt"
#
# 	try:
# 		# Try to open the file for reading
# 		with open(filename, "r") as f:
# 			data = f.read()
# 		# Do something with the data...
# 		print(data)
#
# 	except FileNotFoundError:
# 		# Handle the case where the file doesn't exist
# 		print(f"Error: file {filename} not found.")
#
# 	except PermissionError:
# 		# Handle the case where the user doesn't have permission to read the file
# 		print(f"Error: you do not have permission to read {filename}.")
#
# 	except IOError:
# 		# Handle any other I/O errors that may occur
# 		print("Error: an I/O error occurred while reading the file.")
# - seek(), tell()
# - rb, wb mode & decode(), encode()
# 	- utf-8, ASCII, UTF-16 etc
#
# 	# Open a binary file in read mode
# 	with open('image.jpg', 'rb') as f:
# 		# Read the contents of the file
# 		binary_data = f.read()
#
# 	# Open a binary file in write mode
# 	with open('copy.jpg', 'wb') as f:
# 		# Write the binary data to the new file
# 		f.write(binary_data)
#
#
# Excercises:
# Problem 1: Reversing the contents of a file using file pointers
#
# Write a Python program to read the contents of a file and then reverse its contents using file pointers. In other words, you need to write the contents of the file to a new file in reverse order.
#
# Sample Input: input.txt
# This is a sample file.
# It contains some words.
#
# Sample Output: output.txt
# .sdraw moc sdnuos tniatnoc tI
# .elif elpmas a si sihT
#
#
#
# Problem 2: Copying a file using file pointers
#
# Write a Python program to copy the contents of one file to another file using file pointers. You should be able to copy files of any size.
#
# Sample Input: input.txt
# This is a sample file.
# It contains some words.
#
# Sample Output: output.txt
# This is a sample file.
# It contains some words.
#
# with open('input.txt', 'rb') as f1, open('output.txt', 'wb') as f2:
#
#     f1.seek(0)
#
#     while True:
#
#         data = f1.read(1024)
#
#         if not data:
#             break
#
#         f2.write(data)
#
#
# Find output:
# 	import os
#
# 	staging_dir = './staging/'
# 	final_dir = './final/'
#
# 	def concatenate_files():
# 		filenames = ['file1.txt', 'file2.txt', 'file3.txt']
# 		output_filename = 'concatenated.txt'
#
#
# 		output_file = open(os.path.join(final_dir, output_filename), 'w')
#
#
# 		for filename in filenames:
# 			input_file = open(os.path.join(staging_dir, filename), 'r')
# 			output_file.write(input_file.read())
# 			input_file.close()
#
#
# 		output_file_size = os.path.getsize(os.path.join(final_dir, output_filename))
# 		if output_file_size > 200000:
#
# 			extra_output_filename = 'concatenated_2.txt'
# 			extra_output_file = open(os.path.join(final_dir, extra_output_filename), 'w')
#
#
#
# 			half_size = output_file_size // 2
# 			output_file.seek(half_size)
# 			extra_output_file.write(output_file.read())
# 			output_file.truncate(half_size)
#
# 			extra_output_file.close()
#
# 		output_file.close()
#
# 	concatenate_files()
#
#
# - CSV:
# 	- reader, writer
# 	- next()
# 	- delimiter, quotechar
# 	- DictReader , DictWriter
# 	- Dialect class
#
# - json:
# 	- loads()
# 	- dumps()
# 	- load()
# 	- dump()
# 	- diff between load() vs loads()
# 	- Handling Errors (JSONDecodeError)

# %%
# Python code to illustrate read() mode character wise
file = open(r"C:\Users\PraVEen\Downloads\0502_Qonly1.txt", "r")
print (file.read(25))
# Out:
# may-02:
# topics:
# 	1. pars

# %%
# Python code to create a file
file = open(r'C:\Users\PraVEen\Downloads\1.txt','w')
file.write("This is the write command")
file.write("It allows us to write in a particular file")
file.close()

# %%
file = open(r"C:\Users\PraVEen\Downloads\1.txt", "r")
print (file.read())
# Out:
# This is the write commandIt allows us to write in a particular file

# %%
file = open(r"C:\Users\PraVEen\Downloads\1.txt",'a')
file.write("It allows us for adding a particular line")
file.close()

# %%
file = open(r"C:\Users\PraVEen\Downloads\1.txt", "r")
print (file.read())
# Out:
# This is the write commandIt allows us to write in a particular fileIt allows us for adding a particular line

# %%
# Python code to illustrate with() alongwith write()
with open(r"C:\Users\PraVEen\Downloads\1.txt", "w") as f:
    f.write("Hello World!!!")
with open(r"C:\Users\PraVEen\Downloads\1.txt", "r") as file:
    data = file.readlines()
    for line in data:
        word = line.split()
    print(word)
# Out:
# ['Hello', 'World!!!']

# %%
# Python code to illustrate with() alongwith write()
with open(r"C:\Users\PraVEen\Downloads\1.txt", "r") as f:
    print(f.read())
# Out:
# Hello World!!!

# %%
# Python code to illustrate split() function
with open(r"C:\Users\PraVEen\Downloads\1.txt", "r") as file:
    data = file.readlines()
    for line in data:
        word = line.split()
    print(word)
# Out:
# ['Hello', 'World!!!']

# %%
# Python code to illustrate with() alongwith write()
with open(r"C:\Users\PraVEen\Downloads\1.txt", "w") as f:
    f.writelines("Hello Prash!!!")
with open(r"C:\Users\PraVEen\Downloads\1.txt", "r") as file:
    data = file.readlines()
    for line in data:
        word = line.split()
    print(word)
# Out:
# ['Hello', 'Prash!!!']

# %%
# Program to show various ways to read and write data in a file.
file1 = open(r"C:\Users\PraVEen\Downloads\2.txt","w")
L = ["Ready Aim Fire \n","Ready Aim Fire \n","An empire's fall in just one day \n"]
 
# \n is placed to indicate EOL (End of Line)
file1.write("Imagine Dragons \n")
file1.writelines(L)
file1.close() #to change file access modes
 
file1 = open(r"C:\Users\PraVEen\Downloads\2.txt","r+")
 
print("Output of Read function is ")
print(file1.read())
print(file1.tell())
print()
 
# seek(n) takes the file handle to the nth byte from the beginning.
file1.seek(0)
 
print( "Output of Readline function is ")
print(file1.readline())
print()
 
file1.seek(0)
 
# To show difference between read and readline
print("Output of Read(9) function is ")
print(file1.read(9))
print()
 
file1.seek(0)
 
print("Output of Readline(9) function is ")
print(file1.readline(9))
 
file1.seek(0)

# readlines function
print("Output of Readlines function is ")
print(file1.readlines())
print()
file1.close()
# Out:
# Output of Read function is
# Imagine Dragons
# Ready Aim Fire
# Ready Aim Fire
# An empire's fall in just one day
#
# 87
#
# Output of Readline function is
# Imagine Dragons
#
#
# Output of Read(9) function is
# Imagine D
#
# Output of Readline(9) function is
# Imagine D
# Output of Readlines function is
# ['Imagine Dragons \n', 'Ready Aim Fire \n', 'Ready Aim Fire \n', "An empire's fall in just one day \n"]

# %%
# Open the file in write mode
f1 = open(r"C:\Users\PraVEen\Downloads\output.txt", "w")
 
# Open the input file and get
# the content into a variable data
with open(r"C:\Users\PraVEen\Downloads\imput.txt", "r") as myfile:
    data = myfile.read() 
# For Full Reversing we will store the value of data into new variable data_1 in a reverse order using [start: end: step], where step when passed -1 will reverse the string
data_1 = data[::-1]
 
# Now we will write the fully reverse data in the output1 file using following command
f1.write(data_1)
 
f1.close()

f1 = open(r"C:\Users\PraVEen\Downloads\output.txt", "r")
print(f1.read())
# Out:
# .sdrow emos sniatnoc tI
# .elif elpmas a si sihT

# %%
# Open the file in write mode
f2 = open("output2.txt", "w")
 
 
# Open the input file again and get
# the content as list to a variable data
with open("file.txt", "r") as myfile:
    data = myfile.readlines()
 
# We will just reverse the array using following code
data_2 = data[::-1]
 
# Fully reversing list in the output2 file using following command
f2.writelines(data_2)
 
f2.close()

# %%
Find output:
	import os

	staging_dir = './staging/'
	final_dir = './final/'

	def concatenate_files():
		filenames = ['file1.txt', 'file2.txt', 'file3.txt']
		output_filename = 'concatenated.txt'

		
		output_file = open(os.path.join(final_dir, output_filename), 'w')

		
		for filename in filenames:
			input_file = open(os.path.join(staging_dir, filename), 'r')
			output_file.write(input_file.read())
			input_file.close()

		
		output_file_size = os.path.getsize(os.path.join(final_dir, output_filename))
		if output_file_size > 200000:
			
			extra_output_filename = 'concatenated_2.txt'
			extra_output_file = open(os.path.join(final_dir, extra_output_filename), 'w')

			
			
			half_size = output_file_size // 2
			output_file.seek(half_size)
			extra_output_file.write(output_file.read())
			output_file.truncate(half_size)
			
			extra_output_file.close()
		
		output_file.close()

	concatenate_files()

# %%
# importing csv module
import csv
 
# csv file name
filename = r"C:\Users\PraVEen\Downloads\Employee.csv"
 
# initializing the titles and rows list
fields = []
rows = []
 
# reading csv file
with open(filename, 'r') as csvfile:
    # creating a csv reader object
    csvreader = csv.reader(csvfile)
     
    # extracting field names through first row
    fields = next(csvreader)
 
    # extracting each data row one by one
    for row in csvreader:
        rows.append(row)
 
    # get total number of rows
    print("Total no. of rows: %d"%(csvreader.line_num))
 
# printing the field names
print('Field names are:' + ', '.join(field for field in fields))
 
# printing first 10 rows
print('\nFirst 10 rows are:\n')
for row in rows[:10]:
    # parsing each column of a row
    for col in row:
        print("%10s"%col,end=" "),
    print('\n')
# Out:
# Total no. of rows: 1001
# Field names are:EEID, Full Name, Job Title, Department, Business Unit, Gender, Ethnicity, Age, Hire Date, Annual Salary, Bonus %, Country, City, Exit Date
#
# First 10 rows are:
#
#     E02387 Emily Davis Sr. Manger         IT Research & Development     Female      Black         55   4/8/2016  $141,604         15% United States    Seattle 10/16/2021
#
#     E04105 Theodore Dinh Technical Architect         IT Manufacturing       Male      Asian         59 11/29/1997   $99,975          0%      China  Chongqing
#
#     E02572 Luna Sanders   Director    Finance Speciality Products     Female  Caucasian         50 10/26/2006  $163,099         20% United States    Chicago
#
#     E02832 Penelope Jordan Computer Systems Manager         IT Manufacturing     Female  Caucasian         26  9/27/2019   $84,913          7% United States    Chicago
#
#     E01639  Austin Vo Sr. Analyst    Finance Manufacturing       Male      Asian         55 11/20/1995   $95,409          0% United States    Phoenix
#
#     E00644 Joshua Gupta Account Representative      Sales  Corporate       Male      Asian         57  1/24/2017   $50,994          0%      China  Chongqing
#
#     E01550 Ruby Barnes    Manager         IT  Corporate     Female  Caucasian         27   7/1/2020  $119,746         10% United States    Phoenix
#
#     E04332 Luke Martin    Analyst    Finance Manufacturing       Male      Black         25  5/16/2020   $41,336          0% United States      Miami  5/20/2021
#
#     E04533 Easton Bailey    Manager Accounting Manufacturing       Male  Caucasian         29  1/25/2019  $113,527          6% United States     Austin
#
#     E03838 Madeline Walker Sr. Analyst    Finance Speciality Products     Female  Caucasian         34  6/13/2018   $77,203          0% United States    Chicago

# %%
import csv

with open(r"C:\Users\PraVEen\Downloads\Employee.csv") as csvf:
    csvReader = csv.reader(csvf, delimiter=',',quotechar='|')
for row in rows[:10]:
    # parsing each column of a row
    for col in row:
        print("%10s"%col,end=" "),
    print('\n')
# Out:
#     E02387 Emily Davis Sr. Manger         IT Research & Development     Female      Black         55   4/8/2016  $141,604         15% United States    Seattle 10/16/2021
#
#     E04105 Theodore Dinh Technical Architect         IT Manufacturing       Male      Asian         59 11/29/1997   $99,975          0%      China  Chongqing
#
#     E02572 Luna Sanders   Director    Finance Speciality Products     Female  Caucasian         50 10/26/2006  $163,099         20% United States    Chicago
#
#     E02832 Penelope Jordan Computer Systems Manager         IT Manufacturing     Female  Caucasian         26  9/27/2019   $84,913          7% United States    Chicago
#
#     E01639  Austin Vo Sr. Analyst    Finance Manufacturing       Male      Asian         55 11/20/1995   $95,409          0% United States    Phoenix
#
#     E00644 Joshua Gupta Account Representative      Sales  Corporate       Male      Asian         57  1/24/2017   $50,994          0%      China  Chongqing
#
#     E01550 Ruby Barnes    Manager         IT  Corporate     Female  Caucasian         27   7/1/2020  $119,746         10% United States    Phoenix
#
#     E04332 Luke Martin    Analyst    Finance Manufacturing       Male      Black         25  5/16/2020   $41,336          0% United States      Miami  5/20/2021
# ['E04729,Ezekiel Fong,Vice President,Sales,Research & Development,Male,Asian,56,2/25/2004,"$216,949 ",32%,China,Shanghai,']
# ['E00360,Dylan Thao,Director,Engineering,Manufacturing,Male,Asian,53,10/22/2012,"$168,510 ",29%,United States,Seattle,']
# ['E02284,Josephine Salazar,Field Engineer,Engineering,Speciality Products,Female,Latino,36,3/14/2016,"$85,870 ",0%,Brazil,Sao Paulo,']
# ['E00181,Genesis Hu,Sr. Analyst,Marketing,Corporate,Female,Asian,46,1/15/2002,"$86,510 ",0%,China,Beijing,1/2/2003']
# ['E04168,Mila Juarez,Manager,Sales,Speciality Products,Female,Latino,38,9/21/2017,"$119,647 ",9%,Brazil,Sao Paulo,']
# ['E02861,Daniel Perry,Enterprise Architect,IT,Research & Development,Male,Caucasian,62,4/15/2001,"$80,921 ",0%,United States,Columbus,']
# ...
# ['E02217,William Phillips,Network Architect,IT,Corporate,Male,Black,61,1/27/2004,"$88,478 ",0%,United States,Austin,']
# ['E03519,Eliza Zheng,Computer Systems Manager,IT,Speciality Products,Female,Asian,48,4/20/2014,"$91,679 ",7%,China,Chongqing,']
# ['E01967,John Dang,Director,Sales,Corporate,Male,Asian,58,3/19/1992,"$199,848 ",16%,China,Chongqing,']
# ['E01125,Joshua Yang,Network Engineer,IT,Manufacturing,Male,Asian,34,11/10/2018,"$61,944 ",0%,China,Shanghai,']
# ['E03795,Hazel Young,Sr. Manger,Sales,Speciality Products,Female,Black,30,8/13/2017,"$154,624 ",15%,United States,Austin,']
# ['E00508,Thomas Jung,Sr. Analyst,Accounting,Research & Development,Male,Asian,50,10/23/2009,"$79,447 ",0%,China,Shanghai,']
# ['E02047,Xavier Perez,Sr. Analyst,Sales,Manufacturing,Male,Latino,51,2/26/1998,"$71,111 ",0%,Brazil,Rio de Janerio,']
# ['E01582,Elijah Coleman,Sr. Manger,Sales,Research & Development,Male,Caucasian,53,10/19/2014,"$159,538 ",11%,United States,Miami,']
# ['E02563,Clara Sanchez,Controls Engineer,Engineering,Corporate,Female,Latino,47,10/2/2018,"$111,404 ",0%,Brazil,Rio de Janerio,']
# ['E04872,Isaac Stewart,Director,Marketing,Speciality Products,Male,Caucasian,25,8/15/2020,"$172,007 ",26%,United States,Miami,']
# ['E03159,Claire Romero,Vice President,Marketing,Manufacturing,Female,Latino,37,7/21/2011,"$219,474 ",36%,Brazil,Manaus,']
# ['E01337,Andrew Coleman,Director,Finance,Corporate,Male,Caucasian,41,5/15/2019,"$174,415 ",23%,United States,Miami,']
# ['E00102,Riley Rojas,Network Architect,IT,Speciality Products,Female,Latino,36,1/21/2021,"$90,333 ",0%,Brazil,Rio de Janerio,']
# ['E03637,Landon Thao,HRIS Analyst,Human Resources,Speciality Products,Male,Asian,25,1/21/2021,"$67,299 ",0%,United States,Phoenix,']
# ['E03455,Hadley Ford,Systems Analyst,IT,Research & Development,Female,Caucasian,52,2/23/2005,"$45,286 ",0%,United States,Chicago,']
# ['E03354,Austin Brown,Director,Marketing,Research & Development,Male,Caucasian,48,8/8/2007,"$194,723 ",25%,United States,Phoenix,']
# ['E01225,Christian Fong,Manager,Sales,Research & Development,Male,Asian,49,8/10/2012,"$109,850 ",7%,China,Beijing,2/4/2020']
# ['E01264,Hazel Alvarez,Business Partner,Human Resources,Research & Development,Female,Latino,62,4/19/2014,"$45,295 ",0%,Brazil,Sao Paulo,']
# ['E02274,Isabella Bailey,Network Administrator,IT,Manufacturing,Female,Caucasian,36,8/23/2010,"$61,310 ",0%,United States,Phoenix,']
# ['E02848,Lincoln Huynh,System AdministratorÂ\xa0,IT,Research & Development,Male,Asian,55,11/9/2016,"$87,851 ",0%,China,Chongqing,']
# ['E00480,Hadley Yee,Business Partner,Human Resources,Speciality Products,Female,Asian,31,3/12/2018,"$47,913 ",0%,United States,Seattle,']
# ['E00203,Julia Doan,Business Partner,Human Resources,Speciality Products,Female,Asian,53,9/7/2017,"$46,727 ",0%,United States,Columbus,5/31/2018']
# ['E00647,Dylan Ali,Sr. Manger,Human Resources,Speciality Products,Male,Asian,27,4/16/2021,"$133,400 ",11%,United States,Phoenix,']
# ['E03296,Eloise Trinh,Solutions Architect,IT,Speciality Products,Female,Asian,39,4/22/2020,"$90,535 ",0%,United States,Miami,']
# ['E02453,Dylan Kumar,Sr. Analyst,Marketing,Speciality Products,Male,Asian,55,7/11/2006,"$93,343 ",0%,China,Chongqing,']
# ['E00647,Emily Gupta,HRIS Analyst,Human Resources,Corporate,Female,Asian,44,2/23/2006,"$63,705 ",0%,United States,Miami,']
# ['E02522,Silas Rivera,Vice President,Sales,Corporate,Male,Latino,48,2/28/2000,"$258,081 ",30%,United States,Chicago,']
# ['E00459,Jackson Jordan,Business Partner,Human Resources,Research & Development,Male,Black,48,9/21/2020,"$54,654 ",0%,United States,Phoenix,']
# ['E03007,Isaac Joseph,Analyst,Sales,Manufacturing,Male,Caucasian,54,9/24/1998,"$58,006 ",0%,United States,Seattle,']
# ['E04035,Hailey Lai,Sr. Manger,Finance,Manufacturing,Female,Asian,42,3/18/2011,"$150,034 ",12%,China,Beijing,']
# ['E00952,Leilani Thao,Director,Human Resources,Speciality Products,Female,Asian,38,5/30/2007,"$198,562 ",22%,United States,Seattle,']
# ['E03863,Madeline Watson,Account Representative,Sales,Research & Development,Female,Black,40,5/27/2009,"$62,411 ",0%,United States,Miami,8/14/2021']
# ['E02710,Silas Huang,Engineering Manager,Engineering,Research & Development,Male,Asian,57,1/9/1992,"$111,299 ",12%,United States,Miami,']
# ['E01895,Peyton Walker,Analyst,Marketing,Research & Development,Female,Caucasian,43,7/13/2019,"$41,545 ",0%,United States,Miami,']
# ['E01339,Jeremiah Hernandez,Network Engineer,IT,Manufacturing,Male,Latino,26,4/14/2019,"$74,467 ",0%,United States,Columbus,1/15/2021']
# ['E02938,Jace Washington,Manager,Accounting,Research & Development,Male,Caucasian,44,2/9/2002,"$117,545 ",6%,United States,Phoenix,']
# ['E03379,Landon Kim,Manager,Human Resources,Speciality Products,Male,Asian,50,3/15/2012,"$117,226 ",8%,United States,Phoenix,']
# ['E02153,Peyton Vasquez,Analyst,Accounting,Corporate,Female,Latino,26,1/24/2019,"$55,767 ",0%,United States,Phoenix,']
# ['E00994,Charlotte Baker,Analyst II,Sales,Manufacturing,Female,Caucasian,29,11/17/2016,"$60,930 ",0%,United States,Austin,']
# ['E00943,Elena Mendoza,Director,Sales,Speciality Products,Female,Latino,27,10/24/2018,"$154,973 ",29%,Brazil,Sao Paulo,']
# ['E00869,Nova Lin,Cloud Infrastructure Architect,IT,Manufacturing,Female,Asian,33,10/21/2017,"$69,332 ",0%,United States,Columbus,']
# ['E03457,Ivy Desai,Controls Engineer,Engineering,Research & Development,Female,Asian,59,4/9/2001,"$119,699 ",0%,China,Shanghai,']
# ['E02193,Josephine Acosta,Director,Human Resources,Speciality Products,Female,Latino,40,9/20/2020,"$198,176 ",17%,Brazil,Manaus,']
# ['E00577,Nora Nunez,Analyst II,Finance,Research & Development,Female,Latino,45,8/6/2012,"$58,586 ",0%,Brazil,Sao Paulo,']
# ['E00538,Caleb Xiong,Sr. Account Representative,Sales,Corporate,Male,Asian,38,11/28/2011,"$74,010 ",0%,United States,Chicago,']
# ['E01415,Henry Green,Sr. Account Representative,Sales,Speciality Products,Male,Caucasian,32,2/3/2020,"$96,598 ",0%,United States,Phoenix,']
# ['E00717,Madelyn Chan,Manager,Sales,Speciality Products,Female,Asian,64,5/21/2003,"$106,444 ",5%,United States,Phoenix,']
# ['E00225,Angel Delgado,Director,Finance,Corporate,Male,Latino,31,8/10/2017,"$156,931 ",28%,United States,Seattle,']
# ['E02889,Mia Herrera,Director,Marketing,Research & Development,Female,Latino,43,10/16/2014,"$171,360 ",23%,Brazil,Manaus,']
# ['E04978,Peyton Harris,Enterprise Architect,IT,Research & Development,Female,Caucasian,45,4/5/2009,"$64,505 ",0%,United States,Miami,']
# ['E04163,David Herrera,Engineering Manager,Engineering,Speciality Products,Male,Latino,32,10/9/2021,"$102,298 ",13%,Brazil,Rio de Janerio,']
# ['E01652,Avery Dominguez,Sr. Manger,Sales,Corporate,Female,Latino,27,9/13/2019,"$133,297 ",13%,Brazil,Rio de Janerio,']
# ['E00880,Grace Carter,Sr. Manger,Human Resources,Speciality Products,Female,Black,25,3/17/2021,"$155,080 ",10%,United States,Austin,']
# ['E04335,Parker Allen,Sr. Analyst,Sales,Speciality Products,Male,Caucasian,31,8/13/2018,"$81,828 ",0%,United States,Miami,']
# ['E01300,Sadie Lee,Sr. Manger,Marketing,Corporate,Female,Asian,65,10/24/2000,"$149,417 ",13%,China,Chengdu,']
# ['E03102,Cooper Valdez,Manager,Sales,Corporate,Male,Latino,50,4/25/2012,"$113,269 ",9%,Brazil,Sao Paulo,']
# ['E04089,Sebastian Fong,Sr. Manger,IT,Manufacturing,Male,Asian,46,12/16/2017,"$136,716 ",12%,United States,Austin,']
# ['E02059,Roman Munoz,Sr. Manger,Sales,Speciality Products,Male,Latino,54,10/20/2011,"$122,644 ",12%,United States,Austin,']
# ['E03894,Charlotte Chang,Manager,Sales,Research & Development,Female,Asian,50,5/7/2000,"$106,428 ",7%,United States,Chicago,']
# ['E03106,Xavier Davis,Vice President,Finance,Corporate,Male,Caucasian,36,1/17/2009,"$238,236 ",31%,United States,Seattle,']
# ['E01350,Natalie Carter,Director,Finance,Corporate,Female,Caucasian,64,12/21/2012,"$153,253 ",24%,United States,Austin,']
# ['E02900,Elena Richardson,Manager,Accounting,Manufacturing,Female,Caucasian,34,10/3/2014,"$103,707 ",9%,United States,Columbus,']
# ['E02202,Emilia Bailey,Vice President,Accounting,Speciality Products,Female,Caucasian,41,8/9/2012,"$245,360 ",37%,United States,Austin,']
# ['E02696,Ryan Lu,Development Engineer,Engineering,Speciality Products,Male,Asian,25,7/8/2021,"$67,275 ",0%,United States,Columbus,']
# ['E01722,Asher Huynh,Manager,IT,Manufacturing,Male,Asian,45,1/22/2015,"$101,288 ",10%,United States,Phoenix,']
# ['E04562,Kinsley Martinez,Director,Human Resources,Speciality Products,Female,Latino,52,8/28/1993,"$177,443 ",25%,Brazil,Sao Paulo,']
# ['E00640,Paisley Bryant,Cloud Infrastructure Architect,IT,Manufacturing,Female,Black,37,4/27/2016,"$91,400 ",0%,United States,Chicago,']
# ['E02554,Joshua Ramirez,Vice President,Human Resources,Corporate,Male,Latino,44,9/10/2007,"$181,247 ",33%,Brazil,Sao Paulo,']
# ['E03412,Joshua Martin,Sr. Manger,Human Resources,Research & Development,Male,Black,42,10/20/2003,"$135,558 ",14%,United States,Phoenix,']
# ['E00646,Charles Moore,Analyst,Accounting,Speciality Products,Male,Caucasian,49,12/17/2011,"$56,878 ",0%,United States,Seattle,']
# ['E04670,Angel Do,IT Systems Architect,IT,Speciality Products,Male,Asian,34,9/20/2019,"$94,735 ",0%,China,Beijing,']
# ['E03580,Maverick Medina,Analyst II,Sales,Manufacturing,Male,Latino,39,5/27/2007,"$51,234 ",0%,United States,Seattle,']
# ['E00446,Isaac Han,Vice President,Human Resources,Speciality Products,Male,Asian,31,1/14/2015,"$230,025 ",34%,United States,Phoenix,']
# ['E02363,Eliza Liang,Sr. Manger,Human Resources,Speciality Products,Female,Asian,36,3/11/2010,"$134,006 ",13%,China,Beijing,']
# ['E03718,Zoe Zhou,Manager,Finance,Corporate,Female,Asian,61,10/6/2009,"$103,096 ",7%,China,Beijing,']
# ['E01749,Nathan Lee,Analyst,Accounting,Manufacturing,Male,Asian,29,8/20/2016,"$58,703 ",0%,United States,Columbus,']
# ['E02888,Elijah Ramos,Sr. Manger,IT,Speciality Products,Male,Latino,33,12/24/2012,"$132,544 ",10%,Brazil,Rio de Janerio,']
# ['E01338,Jaxson Coleman,Manager,Finance,Manufacturing,Male,Caucasian,32,4/15/2020,"$126,671 ",9%,United States,Miami,']
# ['E03000,Hailey Hong,Account Representative,Sales,Research & Development,Female,Asian,33,1/22/2021,"$56,405 ",0%,United States,Chicago,']
# ['E01611,Gabriella Zhu,Computer Systems Manager,IT,Speciality Products,Female,Asian,36,11/29/2014,"$88,730 ",8%,China,Chongqing,']
# ['E02684,Aaron Maldonado,Analyst II,Finance,Manufacturing,Male,Latino,39,9/17/2008,"$62,861 ",0%,United States,Seattle,']
# ['E02561,Samantha Vargas,Director,Human Resources,Corporate,Female,Latino,53,7/21/2006,"$151,246 ",21%,Brazil,Sao Paulo,']
# ['E03168,Nora Le,Sr. Manger,IT,Manufacturing,Female,Asian,53,4/12/1997,"$154,388 ",10%,United States,Seattle,']
# ['E00758,Alice Roberts,Director,Human Resources,Manufacturing,Female,Caucasian,54,9/26/1994,"$162,978 ",17%,United States,Miami,5/24/2004']
# ['E03691,Colton Garcia,Solutions Architect,IT,Speciality Products,Male,Latino,55,11/17/1993,"$80,170 ",0%,United States,Miami,']
# ['E01488,Stella Lai,Sr. Analyst,Accounting,Manufacturing,Female,Asian,44,4/28/2021,"$98,520 ",0%,United States,Miami,']
# ['E04415,Leonardo Luong,Manager,Finance,Manufacturing,Male,Asian,52,12/29/1999,"$116,527 ",7%,United States,Phoenix,']
# ['E03278,Nicholas Wong,Director,Sales,Research & Development,Male,Asian,27,11/7/2019,"$174,607 ",29%,United States,Columbus,']
# ['E00282,Jeremiah Castillo,Analyst II,Accounting,Research & Development,Male,Latino,58,4/12/2006,"$64,202 ",0%,United States,Columbus,']
# ['E03305,Cooper Jiang,Analyst II,Accounting,Corporate,Male,Asian,49,7/25/2019,"$50,883 ",0%,China,Chongqing,3/2/2021']
# ['E00559,Penelope Silva,Network Architect,IT,Speciality Products,Female,Latino,36,11/3/2016,"$94,618 ",0%,United States,Columbus,']
# ['E02558,Jose Richardson,Director,Marketing,Research & Development,Male,Caucasian,26,10/15/2019,"$151,556 ",20%,United States,Miami,']
# ['E00956,Eleanor Chau,Development Engineer,Engineering,Research & Development,Female,Asian,37,3/8/2020,"$80,659 ",0%,United States,Phoenix,']
# ['E03858,John Cho,Director,Human Resources,Speciality Products,Male,Asian,47,11/3/2019,"$195,385 ",21%,China,Chengdu,']
# ['E02221,Julian Delgado,Systems Analyst,IT,Speciality Products,Male,Latino,29,5/19/2016,"$52,693 ",0%,Brazil,Rio de Janerio,']
# ['E00126,Isabella Scott,Network Administrator,IT,Research & Development,Female,Caucasian,58,4/26/2016,"$72,045 ",0%,United States,Phoenix,']
# ['E02627,Parker Avila,Analyst II,Marketing,Manufacturing,Male,Latino,47,11/28/2005,"$62,749 ",0%,Brazil,Manaus,']
# ['E03778,Luke Vu,Sr. Manger,Marketing,Speciality Products,Male,Asian,52,6/4/2018,"$154,884 ",10%,China,Shanghai,']
# ['E00481,Jameson Nelson,Network Architect,IT,Research & Development,Male,Caucasian,61,3/8/2016,"$96,566 ",0%,United States,Columbus,']
# ['E02833,Adrian Fernandez,Systems Analyst,IT,Research & Development,Male,Latino,45,8/23/2001,"$54,994 ",0%,United States,Columbus,']
# ['E03902,Madison Hunter,Network Administrator,IT,Corporate,Female,Caucasian,40,2/5/2012,"$61,523 ",0%,United States,Columbus,']
# ['E02310,Jordan Phillips,Vice President,Human Resources,Corporate,Male,Black,45,12/12/2010,"$190,512 ",32%,United States,Columbus,']
# ['E02521,Lily Nguyen,Sr. Analyst,Finance,Speciality Products,Female,Asian,33,1/28/2012,"$95,960 ",0%,China,Chengdu,']
# ['E03545,Sofia Cheng,Vice President,Accounting,Corporate,Female,Asian,63,7/26/2020,"$216,195 ",31%,United States,Miami,']

# %%
DataCaptured = csv.reader(r"C:\Users\PraVEen\Downloads\Employee.csv", delimiter=',', skipinitialspace=True) 

EEID, Department = set(), set()
for row in DataCaptured:
    EEID.add(row[0])
    #Department.add(row[1])
print(EEID)#Department)
# Out:
# {'\\', 'p', '.', 'v', ':', 'c', 'y', 'n', 'd', 'D', 'U', 'a', 'e', 'r', 'm', 'E', 'V', 'C', 'P', 's', 'w', 'l', 'o'}

# %% [markdown]
# JSON Operations:

# %%
import json

# a Python object (dict):
x = {
  "name": "John",
  "age": 30,
  "city": "New York"
}

# convert into JSON:
y = json.dumps(x)

# the result is a JSON string:
print(y)
# Out:
# {"name": "John", "age": 30, "city": "New York"}

# %%
import json
  
# JSON string:
# Multi-line string
x = """{
    "Name": "Jennifer Smith",
    "Contact Number": 7867567898,
    "Email": "jen123@gmail.com",
    "Hobbies":["Reading", "Sketching", "Horse Riding"]
    }"""
  
# parse x:
y = json.loads(x)
  
# the result is a Python dictionary:
print(y)
# Out:
# {'Name': 'Jennifer Smith', 'Contact Number': 7867567898, 'Email': 'jen123@gmail.com', 'Hobbies': ['Reading', 'Sketching', 'Horse Riding']}

# %%
import json
 
# Creating a dictionary
Dictionary ={1:'Welcome', 2:'to',
            3:'Geeks', 4:'for',
            5:'Geeks'}
  
# Converts input dictionary into string and stores it in json_string
json_string = json.dumps(Dictionary)
print('Equivalent json string of input dictionary:',
      json_string)
print("        ")
 
# Checking type of object returned by json.dumps
print(type(json_string))
# Out:
# Equivalent json string of input dictionary: {"1": "Welcome", "2": "to", "3": "Geeks", "4": "for", "5": "Geeks"}
#
# <class 'str'>

# %%
import json
 
 
Dictionary ={(1, 2, 3):'Welcome', 2:'to',
            3:'Geeks', 4:'for',
            5:'Geeks'}
 
 
# Our dictionary contains tuple
# as key, so it is automatically skipped If we have not set skipkeys = True then the code throws the error
json_string = json.dumps(Dictionary,
                         skipkeys = True)
 
print('Equivalent json string of dictionary:',
      json_string)
# Out:
# Equivalent json string of dictionary: {"2": "to", "3": "Geeks", "4": "for", "5": "Geeks"}

# %%
import json
 
 
# We are adding nan values
# (out of range float values)
# in dictionary
Dictionary ={(1, 2, 3):'Welcome', 2:'to',
            3:'Geeks', 4:'for',
            5:'Geeks', 6:float('nan')}
 
# If we hadn't set allow_nan to
# true we would have got
# ValueError: Out of range float
# values are not JSON compliant
json_string = json.dumps(Dictionary,
                         skipkeys = True,
                         allow_nan = True)
 
print('Equivalent json string of dictionary:',
      json_string)
# Out:
# Equivalent json string of dictionary: {"2": "to", "3": "Geeks", "4": "for", "5": "Geeks", "6": NaN}

# %%
import json
 
Dictionary ={(1, 2, 3):'Welcome', 2:'to',
            3:'Geeks', 4:'for',
            5:'Geeks', 6:float('nan')}
 
# If specified, separators should be
# an (item_separator, key_separator)tuple
# Items are separated by '.' and key,
# values are separated by '='
json_string = json.dumps(Dictionary,
                         skipkeys = True,
                         allow_nan = True,
                         indent = 6,
                         separators =(". ", " = "))
 
print('Equivalent json string of dictionary:',
      json_string)
# Out:
# Equivalent json string of dictionary: {
#       "2" = "to".
#       "3" = "Geeks".
#       "4" = "for".
#       "5" = "Geeks".
#       "6" = NaN
# }

# %%
import json
 
Dictionary ={'c':'Welcome', 'b':'to',
            'a':'Geeks'}
 
json_string = json.dumps(Dictionary,
                         indent = 6,
                         separators =(". ", " = "),
                         sort_keys = True)
 
print('Equivalent json string of dictionary:',
      json_string)
# Out:
# Equivalent json string of dictionary: {
#       "a" = "Geeks".
#       "b" = "to".
#       "c" = "Welcome"
# }

# %%
import json
  
# python object(dictionary) to be dumped
dict1 ={
    "emp1": {
        "name": "Lisa",
        "designation": "programmer",
        "age": "34",
        "salary": "54000"
    },
    "emp2": {
        "name": "Elis",
        "designation": "Trainee",
        "age": "24",
        "salary": "40000"
    },
}
  
# the json file where the output must be stored
out_file = open("myfile.json", "w")
  
json.dump(dict1, out_file, indent = 6)
  
out_file.close()

# %%
# Python program to convert JSON to Python
 
 
import json
 
# JSON string
employee ='{"id":"09", "name": "Nitin", "department":"Finance"}'
 
# Convert string to Python dict
employee_dict = json.loads(employee)
print(employee_dict)
 
print(employee_dict['name'])
# Out:
# {'id': '09', 'name': 'Nitin', 'department': 'Finance'}
# Nitin

# %%
# Python program to read json file
  
import json
  
# Opening JSON file
f = open('myfile.json',)
  
# returns JSON object as a dictionary
data = json.load(f)
  
# Iterating through the json list
for i in data['emp1']:
    print(i)
  
# Closing file
f.close()
# Out:
# name
# designation
# age
# salary

# %%
import json

f = open(r'C:\Users\PraVEen\Downloads\sample.json')

data = json.load(f)

for item in data['customers']:
    for x in item['purchase_history']:
        if 'amount' in x:
            print(sum((x['amount']))
#         else:
#             continue
# f.close()
# Out:
#   File "C:\Users\PraVEen\AppData\Local\Temp\ipykernel_14056\2498117074.py", line 13
#     # f.close()
#                ^
# SyntaxError: unexpected EOF while parsing

# %%
import json
f = open(r'C:\Users\PraVEen\Downloads\sample.json')
data = json.load(f)
for item in data['customers']['purchase_history']['amount']:
    print(item['customers']['purchase_history'].get('amount'))
f.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14056\3462887610.py in <module>
#       2 f = open(r'C:\Users\PraVEen\Downloads\sample.json')
#       3 data = json.load(f)
# ----> 4 for item in items['customers']['purchase_history']['amount']:
#       5     print(item['customers']['purchase_history'].get('amount'))
#       6 f.close()
#
# NameError: name 'items' is not defined

# %%
import json

f = open(r'C:\Users\PraVEen\Downloads\sample.json')

data = json.load(f)

for item in data['customers']:
    for x in item['purchase_history']:
        if 'amount' in x:
            print(sum((x['amount'])))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14056\295498917.py in <module>
#       8     for x in item['purchase_history']:
#       9         if 'amount' in x:
# ---> 10             print(sum((x['amount'])))
#
# TypeError: 'float' object is not iterable

# %%
# Out:
# John Smith : 85.245
# Jane Doe : 85.375
